# %%
import yfinance as yf

# %%
msft = yf.Ticker('msft')
#hist = msft.history('max')
msft.history(start='2022-10-24', end='2022-10-25')
# Out:
#                   Open        High         Low   Close    Volume  Dividends  \
# Date
# 2022-10-24  243.759995  247.839996  241.300003  247.25  24911200          0
#
#             Stock Splits
# Date
# 2022-10-24             0

# %%
hist.head(10)
# Out:
#                 Open      High       Low     Close      Volume  Dividends  \
# Date
# 1986-03-13  0.055536  0.063703  0.055536  0.060980  1031788800        0.0
# 1986-03-14  0.060980  0.064247  0.060980  0.063158   308160000        0.0
# 1986-03-17  0.063158  0.064792  0.063158  0.064247   133171200        0.0
# 1986-03-18  0.064247  0.064792  0.062069  0.062613    67766400        0.0
# 1986-03-19  0.062613  0.063158  0.060980  0.061524    47894400        0.0
# 1986-03-20  0.061524  0.061524  0.059347  0.059891    58435200        0.0
# 1986-03-21  0.059891  0.060980  0.057169  0.058258    59990400        0.0
# 1986-03-24  0.058258  0.058258  0.056080  0.056625    65289600        0.0
# 1986-03-25  0.056624  0.057713  0.056080  0.057713    32083200        0.0
# 1986-03-26  0.057713  0.059891  0.057169  0.059347    22752000        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# ...

# %%
import sys


sys.path.insert(0,'../configuration/')
sys.path.insert(1,'../ingestion/')

# %%
from stockExtract import DJIAStockPriceExtractor

# %%
stockExtractor = DJIAStockPriceExtractor()
stockExtractor.extractDJIAStockPriceMax()
# Out:
# loading yaml file d:\data\development\FinAnalytics\FinancialAnalytics_Bits\configuration\yaml\config.yml
# Processig company CRM
# Removing CRM history file D:\data\development\FinAnalytics\FinancialAnalytics_Bits\stocks_data\ticker_data\CRM\CRM_hist.parquet
# Processig company WBA
# Removing WBA history file D:\data\development\FinAnalytics\FinancialAnalytics_Bits\stocks_data\ticker_data\WBA\WBA_hist.parquet
# Processig company V
# Removing V history file D:\data\development\FinAnalytics\FinancialAnalytics_Bits\stocks_data\ticker_data\V\V_hist.parquet
# Processig company NKE
# Removing NKE history file D:\data\development\FinAnalytics\FinancialAnalytics_Bits\stocks_data\ticker_data\NKE\NKE_hist.parquet
# Processig company UNH
# Removing UNH history file D:\data\development\FinAnalytics\FinancialAnalytics_Bits\stocks_data\ticker_data\UNH\UNH_hist.parquet
# Processig company TRV
# ...

# %%
df = stockExtractor.DJIACompaniesStockPriceDF
df['return'] = stockExtractor.DJIACompaniesStockPriceDF.groupby('symbol')['Close'].pct_change().mul(100)
df

# %%
## Extract news api 
from newAPIExtract import NewsAPIExtract
newsAPI = NewsAPIExtract()
newsAPI.extractDJIACompaniesNews()

# %%
from processSentimentScore import ProcessSentimentScore

processSentiment = ProcessSentimentScore()

processSentiment.processNewsAPISentimentScore()
# Out:
# loading yaml file d:\data\development\FinAnalytics\FinancialAnalytics_Bits\configuration\yaml\config.yml
# loading yaml file d:\data\development\FinAnalytics\FinancialAnalytics_Bits\configuration\yaml\config.yml
# Processing Symbol : CRM
# Saving the file with the location :: D:\data\development\FinAnalytics\FinancialAnalytics_Bits\stocks_data\senti_data\newsAPI\CRM\CRM.parquet
# Processing Symbol : WBA
# Saving the file with the location :: D:\data\development\FinAnalytics\FinancialAnalytics_Bits\stocks_data\senti_data\newsAPI\WBA\WBA.parquet
# Processing Symbol : V
# Saving the file with the location :: D:\data\development\FinAnalytics\FinancialAnalytics_Bits\stocks_data\senti_data\newsAPI\V\V.parquet
# Processing Symbol : NKE
# Saving the file with the location :: D:\data\development\FinAnalytics\FinancialAnalytics_Bits\stocks_data\senti_data\newsAPI\NKE\NKE.parquet
# Processing Symbol : UNH
# ...
